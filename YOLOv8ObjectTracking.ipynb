# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.4/799.4 kB 8.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/*zip
# Out:
#  /content/drive/MyDrive/app.zip
#  /content/drive/MyDrive/caltech101.zip
#  /content/drive/MyDrive/contiguous-area-detector-alpha.zip
#  /content/drive/MyDrive/Documentation-c-a-d.zip
#  /content/drive/MyDrive/frames1.zip
#  /content/drive/MyDrive/frames.zip
#  /content/drive/MyDrive/imager-web-app-0.0.1.zip
# '/content/drive/MyDrive/images+(2).zip'
#  /content/drive/MyDrive/pretrained.zip
# '/content/drive/MyDrive/Weather_yolo_img_clsf_data+(1).zip'
#  /content/drive/MyDrive/YOLO+Videos+for+inference.zip
#  /content/drive/MyDrive/zoi-app-edgelib.3.zip

# %%
# !mkdir -p /content/drive/MyDrive/CV\ Course/DATA/YOLO\ OBJECT\ TRACKER/

# %%
# %cd /content/drive/MyDrive/CV\ Course/DATA/YOLO\ OBJECT\ TRACKER/
# Out:
# /content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER

# %%
# !unzip /content/drive/MyDrive/Y*zip
# Out:
# Archive:  /content/drive/MyDrive/YOLO+Videos+for+inference.zip
#   inflating: YOLO OBJECT TRACKER/benchpress.mp4
#   inflating: YOLO OBJECT TRACKER/snowy.mp4
#   inflating: YOLO OBJECT TRACKER/livingroom.mp4
#   inflating: YOLO OBJECT TRACKER/PEOPLE.mp4
#   inflating: YOLO OBJECT TRACKER/straight cars.mp4
#   inflating: YOLO OBJECT TRACKER/Playing Chess.mp4
#   inflating: YOLO OBJECT TRACKER/hiking.mp4
#   inflating: YOLO OBJECT TRACKER/rainy.mp4
#   inflating: YOLO OBJECT TRACKER/footlball playing.mp4
#   inflating: YOLO OBJECT TRACKER/sunny.mp4
#   inflating: YOLO OBJECT TRACKER/CARS.mp4
#   inflating: YOLO OBJECT TRACKER/potholes.mp4
#   inflating: YOLO OBJECT TRACKER/water.mp4
#   inflating: YOLO OBJECT TRACKER/cloudy.mp4
#   inflating: YOLO OBJECT TRACKER/hardhat original.mp4

# %%
# !apt install tree -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (142 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 121925 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# %cd /content
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load a model
# model = YOLO("yolov8n.pt")  #  ---  detection (n, s, m, l, x)
# model = YOLO("yolov8n-cls.pt")  #  ---  classification
# model = YOLO("yolov8n-seg.pt")  #  ---  segmentation
# model = YOLO("yolov8n-pose.pt")  #  --- Pose / keypoint detection

# %%
#  ---  detection
model = YOLO("yolov8n.pt")
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/PEOPLE.mp4', save=True)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 165MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/341) /content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/PEOPLE.mp4: 384x640 37 persons, 2 birds, 86.5ms
# video 1/1 (frame 2/341) /content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/PEOPLE.mp4: 384x640 38 persons, 3 birds, 7.2ms
# ...

# %%
# !ls -lh /content/runs/detect/predict/
# Out:
# total 105M
# -rw-r--r-- 1 root root 105M Jul  5 22:05 PEOPLE.avi

# %%
print("hello")
# Out:
# hello

# %%
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/PEOPLE.mp4', save=True, stream=True, show=True, conf=0.7)
# stream option takes less RAM, show will show the prediction (but doesn't work in colab notebook)
