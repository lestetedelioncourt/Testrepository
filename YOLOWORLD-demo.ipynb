# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.1/800.1 kB 1.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLOWorld

model = YOLOWorld('yolov8s-world.pt')
results = model.predict('/content/street.jpg', save=True, device='cpu')
# Out:
# ...
# 100%|██████████| 25.9M/25.9M [00:00<00:00, 140MB/s]
# image 1/1 /content/street.jpg: 448x640 7 persons, 1 bicycle, 2 handbags, 1 tie, 842.9ms
# Speed: 31.5ms preprocess, 842.9ms inference, 30.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %%
import cv2

img = cv2.imread('/content/runs/detect/predict/street.jpg')
img
# Out:
# array([[[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [202, 202, 202],
#         [188, 188, 188],
#         [ 56,  56,  56]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [129, 129, 129],
#         [214, 214, 214],
#         [153, 153, 153]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [ 92,  92,  92],
#         [218, 218, 218],
#         [147, 147, 147]],
#
#        ...,
#
#        [[ 15,  15,  15],
#         [ 17,  17,  17],
#         [ 14,  14,  14],
#         ...,
#         [ 25,  25,  25],
#         [ 25,  25,  25],
#         [ 37,  37,  37]],
#
#        [[  1,   1,   1],
#         [  5,   5,   5],
#         [  1,   1,   1],
#         ...,
#         [ 34,  34,  34],
#         [ 22,  22,  22],
#         [ 50,  50,  50]],
#
#        [[ 22,  22,  22],
#         [ 24,  24,  24],
#         [  6,   6,   6],
# ...

# %%
results = model.predict('/content/street2.jpg', save=True, device='cpu')
# Out:
# image 1/1 /content/street2.jpg: 384x640 10 persons, 2 stop signs, 1 dog, 1 umbrella, 1 handbag, 608.5ms
# Speed: 4.5ms preprocess, 608.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict

# %%
img = cv2.imread('/content/runs/detect/predict/street2.jpg')
img
# Out:
# array([[[ 87,  74, 160],
#         [ 47,  32, 130],
#         [ 26,   7, 134],
#         ...,
#         [ 59,  58,  54],
#         [ 46,  45,  41],
#         [ 20,  19,  15]],
#
#        [[114, 100, 188],
#         [ 55,  41, 142],
#         [ 34,  16, 141],
#         ...,
#         [ 46,  45,  41],
#         [ 44,  43,  39],
#         [ 19,  18,  14]],
#
#        [[120, 108, 198],
#         [ 53,  41, 141],
#         [ 33,  17, 142],
#         ...,
#         [ 33,  34,  30],
#         [ 33,  32,  28],
#         [ 15,  14,  10]],
#
#        ...,
#
#        [[ 41,  41,  41],
#         [ 53,  53,  53],
#         [ 57,  59,  59],
#         ...,
#         [ 34,  46,  46],
#         [ 28,  40,  40],
#         [ 26,  38,  38]],
#
#        [[ 41,  41,  41],
#         [ 51,  51,  51],
#         [ 55,  57,  57],
#         ...,
#         [ 32,  44,  44],
#         [ 25,  37,  37],
#         [ 25,  37,  37]],
#
#        [[ 40,  40,  40],
#         [ 51,  51,  51],
#         [ 54,  56,  56],
# ...

# %%
model.set_classes(['person', 'handbag'])
results = model.predict('/content/street2.jpg', save=True, device='cpu')
img = cv2.imread('/content/runs/detect/predict/street2.jpg')
img
# Out:
# requirements: Ultralytics requirement ['git+https://github.com/ultralytics/CLIP.git'] not found, attempting AutoUpdate...
# ...
#   Cloning https://github.com/ultralytics/CLIP.git to /tmp/pip-req-build-w2i1qirk
#   Resolved https://github.com/ultralytics/CLIP.git to commit 74d72722e3b7c2a28961a805b20b5a7c05a75cf8
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.2 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1381946 sha256=c1e6b99d771f9fe9501274ec6b55d4dc9aaadcd163aba8cc7a44226d08d359b5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j40npt74/wheels/2e/25/92/e26f2a227599930e19a8188891e9600b6dd36721a0f8d6ef40
# Successfully built clip
# ...
#
# requirements: AutoUpdate success ✅ 14.7s, installed 1 package: ['git+https://github.com/ultralytics/CLIP.git']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8s-world.pt')
model.set_classes(['tie', 'person'])
model.save('custom_yolovs.pt')

# %%
model = YOLO('custom_yolovs.pt')
results = model.predict('/content/street.jpg', save=True, device='cpu')
img = cv2.imread('/content/runs/detect/predict2/street.jpg')
img
# Out:
# image 1/1 /content/street.jpg: 448x640 1 tie, 7 persons, 525.3ms
# Speed: 3.1ms preprocess, 525.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3
# array([[[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [202, 202, 202],
#         [188, 188, 188],
#         [ 56,  56,  56]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [129, 129, 129],
#         [214, 214, 214],
#         [153, 153, 153]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [ 92,  92,  92],
#         [218, 218, 218],
#         [147, 147, 147]],
#
#        ...,
#
#        [[ 15,  15,  15],
#         [ 17,  17,  17],
#         [ 14,  14,  14],
#         ...,
#         [ 25,  25,  25],
#         [ 25,  25,  25],
#         [ 37,  37,  37]],
#
#        [[  1,   1,   1],
#         [  5,   5,   5],
# ...
