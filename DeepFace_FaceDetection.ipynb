# %%
# !pip install deepface
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.5/105.5 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 10.5 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=cfe547b6750eb3cb3a494720cfead4a2a7e52d9196da35fc036da2f3947e1254
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...
# 24-07-12 19:36:21 - Directory /root/.deepface created
# 24-07-12 19:36:21 - Directory /root/.deepface/weights created

# %%
from retinaface import RetinaFace

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
faces = RetinaFace.extract_faces('/content/facepic6.jpg')
faces
# Out:
# 24-07-12 19:38:11 - retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# To: /root/.deepface/weights/retinaface.h5
# 100%|██████████| 119M/119M [00:00<00:00, 156MB/s]
# [array([[[ 32,  40,  43],
#          [ 26,  35,  44],
#          [ 25,  34,  43],
#          ...,
#          [ 87,  79,  77],
#          [ 77,  69,  67],
#          [ 73,  67,  67]],
#
#         [[ 31,  36,  39],
#          [ 29,  38,  45],
#          [ 26,  35,  42],
#          ...,
#          [ 80,  72,  70],
#          [ 86,  78,  76],
#          [ 81,  75,  75]],
#
#         [[ 31,  36,  40],
#          [ 25,  34,  39],
#          [ 24,  33,  38],
#          ...,
#          [ 83,  75,  73],
#          [ 95,  89,  89],
#          [ 91,  85,  85]],
#
#         ...,
#
#         [[223, 233, 232],
#          [231, 237, 237],
# ...

# %%
img1 = cv2.imread('/content/face01.jpg')
img2 = cv2.imread('/content/face02.jpg')

from google.colab.patches import cv2_imshow

cv2_imshow(img1)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=957x960>
# <PIL.Image.Image image mode=RGB size=450x600>

# %%
result = DeepFace.verify(img1, img2, model_name=models[0])
result
# Out:
# {'verified': True,
#  'distance': 0.672915009487939,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 206,
#    'y': 404,
#    'w': 364,
#    'h': 364,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 299,
#    'y': 73,
#    'w': 136,
#    'h': 136,
#    'left_eye': (392, 119),
#    'right_eye': (334, 120)}},
#  'time': 0.87}

# %%
wimg3 = cv2.imread('/content/cap01.jpg')
img4 = cv2.imread('/content/cap02.jpg')

cv2_imshow(img3)
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=334x406>
# <PIL.Image.Image image mode=RGB size=227x240>

# %%
result = DeepFace.verify(img4, img3)
result
# Out:
# {'verified': False,
#  'distance': 0.8775254851026816,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 78,
#    'y': 43,
#    'w': 74,
#    'h': 74,
#    'left_eye': (130, 69),
#    'right_eye': (98, 70)},
#   'img2': {'x': 163,
#    'y': 124,
#    'w': 127,
#    'h': 127,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 0.24}

# %%
models = [ "VGG-Face", "Facenet", "OpenFace", "DeepFace", "DeepID", "Arcface", "Dlib", "SFace"]
metrics = [ "cosine", "euclidean", "euclidean_l2"]
backends = [ "opencv", "ssd", "dlib", "mtcnn", "retinaaface", "mediapipe", "yolov8", "yunet", "fastmtcnn"]

# %%
dfs = DeepFace.find(img_path='/content/faces/facepic6.jpg', db_path='/content/faces/')
# Out:
# 24-07-12 20:57:59 - Found 21 newly added image(s), 0 removed image(s), 0 replaced image(s).
# Finding representations:   0%|          | 0/21 [00:00<?, ?it/s]
# 24-07-12 20:58:00 - 🔴 Exception while extracting faces from /content/faces/cap3.jpg: Face could not be detected in /content/faces/cap3.jpg.Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Finding representations:  38%|███▊      | 8/21 [00:02<00:04,  3.19it/s]
# 24-07-12 20:58:02 - 🔴 Exception while extracting faces from /content/faces/cap04.JPG: Face could not be detected in /content/faces/cap04.JPG.Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# 24-07-12 20:58:02 - 🔴 Exception while extracting faces from /content/faces/cap4.jpg: Face could not be detected in /content/faces/cap4.jpg.Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# ...

# %%
dfs
# Out:
# [                      identity                                      hash  \
#  0  /content/faces/facepic6.jpg  ee6287f9ba9658f836ec3acc65d76d66e57426ed
#
#     target_x  target_y  target_w  target_h  source_x  source_y  source_w  \
#  0       223        59        71        71       223        59        71
#
#     source_h  threshold  distance
#  0        71       0.68       0.0  ,
#                        identity                                      hash  \
#  0  /content/faces/facepic6.jpg  ee6287f9ba9658f836ec3acc65d76d66e57426ed
#  1  /content/faces/facepic6.jpg  ee6287f9ba9658f836ec3acc65d76d66e57426ed
#
#     target_x  target_y  target_w  target_h  source_x  source_y  source_w  \
#  0       136        71        73        73       136        71        73
#  1       252       212        79        79       136        71        73
#
#     source_h  threshold      distance
#  0        73       0.68 -2.220446e-16
#  1        73       0.68  6.310041e-01  ,
# ...

# %%
dfs2 = DeepFace.find(img_path='/content/faces/jen1.jpg',
                     db_path='/content/faces/',
                     enforce_detection=False,
                     threshold=0.3)
dfs2
# Out:
# 24-07-12 21:11:28 - Searching /content/faces/jen1.jpg in 22 length datastore
# 24-07-12 21:11:28 - find function duration 0.1537799835205078 seconds
# [                  identity                                      hash  \
#  0  /content/faces/jen1.jpg  77e13fbb91e6657c2439ab4627d611867b9ca17d
#
#     target_x  target_y  target_w  target_h  source_x  source_y  source_w  \
#  0       -17        10       247       247       -17        10       247
#
#     source_h  threshold  distance
#  0       247        0.3       0.0  ]

# %%
# !rm faces/facepic*

# %%
# !cp jen* faces/

# %%
# !ls faces
# Out:
# cap01.jpg  ds_model_vggface_detector_opencv_aligned_normalization_base_expand_0.pkl  lhyza.JPG
# cap02.jpg  face01.jpg								     ricky1.jpg
# cap03.JPG  face02.jpg								     ricky2.jpg
# cap04.JPG  jen1.jpg								     ricky3.jpg
# cap1.JPG   jen2.jpg								     ricky4.jpg
# cap2.JPG   jen3.jpg								     ricky5.jpg
# cap3.jpg   jen4.jpg								     ricky6.jpg
# cap4.jpg   jen5.jpg

# %%
objs = DeepFace.analyze(img_path='/content/jen5.jpg')
objs
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  5.65it/s]
# [{'emotion': {'angry': 0.00508689736307133,
#    'disgust': 2.887527195127859e-06,
#    'fear': 0.03024077450390905,
#    'happy': 46.30865156650543,
#    'sad': 0.1982041634619236,
#    'surprise': 0.017937540542334318,
#    'neutral': 53.439879417419434},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 101,
#    'y': 107,
#    'w': 147,
#    'h': 147,
#    'left_eye': (197, 158),
#    'right_eye': (141, 167)},
#   'face_confidence': 0.9,
#   'age': 31,
#   'gender': {'Woman': 99.99996423721313, 'Man': 3.602628453336365e-05},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 0.13196878135204315,
#    'indian': 0.7736968342214823,
#    'black': 0.017758372996468097,
#    'white': 60.94192862510681,
#    'middle eastern': 24.610717594623566,
#    'latino hispanic': 13.523934781551361},
#   'dominant_race': 'white'}]
