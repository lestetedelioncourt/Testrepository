# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.4/799.4 kB 7.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8n-pose.pt')
# Out:
# ...
# 100%|██████████| 6.52M/6.52M [00:00<00:00, 142MB/s]

# %%
# resuls = model.train(data='config.yaml', epochs=100, imgsz=640) # example code for training using a YAML file

# if using the command line

# !yolo train data=coco128.yaml model=model epochs=100 imgsz=640

# %%
import cv2
from google.colab.patches import cv2_imshow

img_path = '/content/street.jpg'
img = cv2.imread(img_path)

results = model.predict(img_path, save=True, imgsz=320, conf=0.5) # conf == confidence value
# Out:
# image 1/1 /content/street.jpg: 224x320 1 person, 182.4ms
# Speed: 12.0ms preprocess, 182.4ms inference, 1235.5ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to runs/pose/predict

# %%
img = cv2.imread('/content/runs/pose/predict/street.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x512>

# %%
img_path = '/content/street2.jpg'

results = model.predict(img_path, save=True, imgsz=320, conf=0.5)
# Out:
# image 1/1 /content/street2.jpg: 192x320 1 person, 146.6ms
# Speed: 1.4ms preprocess, 146.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to runs/pose/predict

# %%
img = cv2.imread('/content/runs/pose/predict/street2.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x431>
