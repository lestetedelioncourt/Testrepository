# %%
import matplotlib.pyplot as plt

# %%
x=plt.imread('ado000.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado001.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado002.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado003.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado004.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado005.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado006.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado007.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado008.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado009.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado001.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado011.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado012.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado013.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado014.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado015.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado016.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado017.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado018.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado019.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado020.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado021.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado022.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado023.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado024.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado025.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado026.JPG')
plt.imshow(x)
plt.show()
x=plt.imread('ado027.JPG')
plt.imshow(x)
plt.show()
